# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# # Open the file using read_csv

# %%
df = pd.read_csv('transaction_data (1).csv') #Opens file 
df
# Out:
#       TransactionID  CustID       Date        Employee  ProductID  \
# 0             10258       1  7/17/2023   Nancy Davolio         32
# 1             10275       2   8/7/2023   Nancy Davolio         24
# 2             10275       2   8/7/2023   Nancy Davolio         59
# 3             10292       3  8/28/2023   Nancy Davolio         20
# 4             10293       4  8/29/2023   Nancy Davolio         18
# ...             ...     ...        ...             ...        ...
# 1348          11016      20  4/10/2025  Anne Dodsworth         31
# 1349          11016      20  4/10/2025  Anne Dodsworth         36
# 1350          11058      82  4/29/2025  Anne Dodsworth         21
# 1351          11058      82  4/29/2025  Anne Dodsworth         60
# 1352          11058      82  4/29/2025  Anne Dodsworth         61
#
#                  ProductName  VendorID              ProductVendor  UnitPrice  \
# 0         Mascarpone Fabioli        14    Formaggi Fortini s.r.l.       25.6
# ...

# %%
#Shows every single row by not having a row max
pd.options.display.max_rows = None 
df
# Out:
#       TransactionID  CustID        Date          Employee  ProductID  \
# 0             10258       1   7/17/2023     Nancy Davolio         32
# 1             10275       2    8/7/2023     Nancy Davolio         24
# 2             10275       2    8/7/2023     Nancy Davolio         59
# 3             10292       3   8/28/2023     Nancy Davolio         20
# 4             10293       4   8/29/2023     Nancy Davolio         18
# 5             10293       4   8/29/2023     Nancy Davolio         24
# 6             10293       4   8/29/2023     Nancy Davolio         63
# 7             10293       4   8/29/2023     Nancy Davolio         75
# 8             10304       4   9/12/2023     Nancy Davolio         59
# 9             10304       4   9/12/2023     Nancy Davolio         71
# 10            10306       5   9/16/2023     Nancy Davolio         30
# 11            10306       5   9/16/2023     Nancy Davolio         53
# 12            10306       5   9/16/2023     Nancy Davolio         54
# ...

# %%
df[['TransactionID', 'CustID', 'ProductID', 'VendorID', 'ProductVendor', 'UnitPrice', 'Quantity', 'Subtotal', 'Tax(8%)', 'OrderTotal']].describe().round(2)
# Out:
#        TransactionID   CustID  ProductID  VendorID  UnitPrice  Quantity  \
# count        1353.00  1353.00    1353.00   1353.00    1353.00   1353.00
# mean        10661.18    38.94      40.39     14.32      25.91     12.63
# std           243.09    25.06      22.28      8.22      28.61      6.40
# min         10248.00     1.00       1.00      1.00       2.00      1.00
# 25%         10454.00    17.00      21.00      7.00      12.00      7.00
# 50%         10656.00    35.00      41.00     14.00      18.40     12.00
# 75%         10864.00    60.00      60.00     21.00      31.23     20.00
# max         11077.00    89.00      77.00     29.00     263.50     24.00
#
#        Subtotal  Tax(8%)  OrderTotal
# count   1353.00  1353.00     1353.00
# mean     324.54    25.96      350.50
# std      403.98    32.32      436.30
# min        4.80     0.38        5.18
# 25%      100.00     8.00      108.00
# 50%      210.00    16.80      226.80
# 75%      394.00    31.52      425.52
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1353 entries, 0 to 1352
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TransactionID  1353 non-null   int64
#  1   CustID         1353 non-null   int64
#  2   Date           1353 non-null   object
#  3   Employee       1353 non-null   object
#  4   ProductID      1353 non-null   int64
#  5   ProductName    1353 non-null   object
#  6   VendorID       1353 non-null   int64
#  7   ProductVendor  1353 non-null   object
#  8   UnitPrice      1353 non-null   float64
#  9   Quantity       1353 non-null   int64
#  10  Subtotal       1353 non-null   float64
#  11  Tax(8%)        1353 non-null   float64
#  12  OrderTotal     1353 non-null   float64
# dtypes: float64(4), int64(5), object(4)
# memory usage: 137.5+ KB

# %%
df.head(10)
# Out:
#    TransactionID  CustID       Date       Employee  ProductID  \
# 0          10258       1  7/17/2023  Nancy Davolio         32
# 1          10275       2   8/7/2023  Nancy Davolio         24
# 2          10275       2   8/7/2023  Nancy Davolio         59
# 3          10292       3  8/28/2023  Nancy Davolio         20
# 4          10293       4  8/29/2023  Nancy Davolio         18
# 5          10293       4  8/29/2023  Nancy Davolio         24
# 6          10293       4  8/29/2023  Nancy Davolio         63
# 7          10293       4  8/29/2023  Nancy Davolio         75
# 8          10304       4  9/12/2023  Nancy Davolio         59
# 9          10304       4  9/12/2023  Nancy Davolio         71
#
#               ProductName  VendorID                    ProductVendor  \
# 0      Mascarpone Fabioli        14          Formaggi Fortini s.r.l.
# 1        Guaran Fantstica        10        Refrescos Americanas LTDA
# 2    Raclette Courdavault        28                      Gai pturage
# ...

# %%
df.head(), df.columns
# Out:
# (   TransactionID  CustID       Date       Employee  ProductID  \
#  0          10258       1  7/17/2023  Nancy Davolio         32
#  1          10275       2   8/7/2023  Nancy Davolio         24
#  2          10275       2   8/7/2023  Nancy Davolio         59
#  3          10292       3  8/28/2023  Nancy Davolio         20
#  4          10293       4  8/29/2023  Nancy Davolio         18
#
#                ProductName  VendorID              ProductVendor  UnitPrice  \
#  0      Mascarpone Fabioli        14    Formaggi Fortini s.r.l.       25.6
#  1        Guaran Fantstica        10  Refrescos Americanas LTDA        3.6
#  2    Raclette Courdavault        28                Gai pturage       44.0
#  3  Sir Rodney's Marmalade         8   Specialty Biscuits, Ltd.       64.8
#  4        Carnarvon Tigers         7              Pavlova, Ltd.       50.0
#
#     Quantity  Subtotal  Tax(8%)  OrderTotal
#  0         6     153.6    12.29      165.89
#  1        12      43.2     3.46       46.66
# ...

# %% [markdown]
# # Top 10 Items Sold

# %%
# Get insights for top sales

# %%
top_sold_items = df.groupby('ProductName')['Quantity'].sum().sort_values(ascending=False).head(10)
top_sold_items # Shows me the top 10 items sold in the list
# Out:
# ProductName
# Gnocchi di nonna Alice             454
# Jack's New England Clam Chowder    431
# Guaran Fantstica                   429
# Chang                              407
# Ikura                              381
# Camembert Pierrot                  373
# Tarte au sucre                     372
# Gorgonzola Telino                  358
# Rhnbru Klosterbier                 335
# Tourtire                           330
# Name: Quantity, dtype: int64

# %%
plt.title('Top 10 Items Sold')
top_sold_items.plot(kind='barh', color='skyblue')
plt.xlabel('Product Name')
plt.ylabel('Total Sold')

plt.show()

# %% [markdown]
# # Employee Sales

# %%
unique_names = df['Employee'].unique() 
unique_names #Many names in this file, so I condenced the list to see how many names there are
# Out:
# array(['Nancy Davolio', 'Andrew Fuller', 'Janet Leverling',
#        'Margaret Peacock', 'Steven Buchanan', 'Michael Suyama',
#        'Robert King', 'Laura Callahan', 'Anne Dodsworth'], dtype=object)

# %%
top_sales_people = df.groupby('Employee')['OrderTotal'].sum().sort_values(ascending=False).head(3)
top_sales_people
# Out:
# Employee
# Margaret Peacock    102093.97
# Nancy Davolio        75095.44
# Janet Leverling      61935.82
# Name: OrderTotal, dtype: float64

# %%
margaret_sales = df[df['Employee'] == 'Margaret Peacock']

margaret_top_sell_item = margaret_sales.groupby('ProductName')['Quantity'].sum().sort_values(ascending=False).head(3) #This shows the item that is sold most by Nancy

margaret_top_sell_item
# Out:
# ProductName
# Tarte au sucre            127
# Gnocchi di nonna Alice    104
# Chai                      102
# Name: Quantity, dtype: int64

# %% [markdown]
# # Nancy Davolio Sales

# %%
nancy_sales = df[df['Employee'] == 'Nancy Davolio'] #This helps me find all the sales that were made by Nancy

nancy_top_sell_item = nancy_sales.groupby('ProductName')['Quantity'].sum().sort_values(ascending=False).head(3) #This shows the item that is sold most by Nancy

nancy_top_sell_item
# Out:
# ProductName
# Scottish Longbreads    94
# Flotemysost            93
# Steeleye Stout         89
# Name: Quantity, dtype: int64

# %% [markdown]
# # Janet Leverling Sales

# %%
# These lines of code give me the results of Jane Leverling
janet_sales = df[df['Employee'] == 'Janet Leverling']

janet_top_sell_item = janet_sales.groupby('ProductName')['Quantity'].sum().sort_values(ascending=False).head(3) #This shows the item that is sold most by Nancy

janet_top_sell_item
# Out:
# ProductName
# Filo Mix             113
# Ipoh Coffee          108
# Gumbr Gummibrchen    104
# Name: Quantity, dtype: int64
